# %% [markdown]
# # Homework 1 (HW1)
#
# ---
# By the end of this homework we expect you to be able to:
# 1. Load data from different formats using [pandas](https://pandas.pydata.org/);
# 2. Navigate the documentation of Python packages by yourself;
# 3. Filter and tidy up noisy data sets;
# 4. Aggregate your data in different (and hopefully helpful) ways; and
# 5. Create meaningful visualizations to analyze the data!
# ---
#
# ## Important Dates
#
# - Homework release: Fri 2 Oct 2020
# - **Homework due**: Fri 16 Oct 2020, 23:59
# - Grade release: Fri 23 Oct 2020
#
# ---
#
# ##  Some rules
#
# 1. You are allowed to use any built-in Python library that comes with Anaconda. If you want to use an external library, you have to justify your choice.
# 2. Make sure you use the `data` folder provided in the repository in **read-only** mode.
# 3. Be sure to provide a textual description of your thought process, the assumptions you made, the solution you implemented, and explanations for your answers. A notebook that only has code cells will not suffice.
# 4. For questions containing the **/Discuss:/** prefix, answer not with code, but with a textual explanation (in either comments or markdown).
# 5. Back up any hypotheses and claims with data, since this is an important aspect of the course.
# 6. Please write all your comments in English, and use meaningful variable names in your code. Your repo should have a single notebook (plus the required data files) in the master branch. If there are multiple notebooks present, we will not grade anything.
# 7. Also, be sure to hand in a fully-run and evaluated notebook. We will not run your notebook for you, we will grade it as is, which means that only the results contained in your evaluated code cells will be considered, and we will not see the results in unevaluated code cells. In order to check whether everything looks as intended, you can check the rendered notebook on the GitHub website once you have pushed your solution there.
# 8. Make sure to print results or dataframes that confirm you have properly addressed the task.
#
#
#
# ## Context
#
# The coronavirus pandemic has led to the implementation of unprecedented non-pharmaceutical interventions ranging from case isolation to national lockdowns. These interventions, along with the disease itself, have created massive shifts in people’s lives. For instance, in mid-May 2020, more than one third of the global population was under lockdown, and millions have since lost their jobs or have moved to work-from-home arrangements.
#
#
# Importantly, the disease has shifted people's [needs](https://en.wikipedia.org/wiki/Toilet_paper), [interests](https://en.wikipedia.org/wiki/TikTok), and [concerns](https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Switzerland) across the globe.
#
# In this homework, we will take a deep dive into Wikipedia data and try to uncover what changed with the pandemic. More specifically, we will be focusing on Wikipedia pageviews, that is, how many people read each article on Wikipedia each day.
# A nice graphical user interface for playing with Wikipedia pageviews is available [here](https://pageviews.toolforge.org/?project=en.wikipedia.org&platform=all-access&agent=user&redirects=0&range=latest-20&pages=Cat|Dog).
# Also, the Wikimedia Foundation releases dump files with the number of pageviews per article across all Wikimedia websites, including Wikipedia in all its language editions [(amazing, right?)](https://dumps.wikimedia.org/other/pagecounts-ez/).
#
# #### But wait, what is a pageview?
#
# > A pageview or page view, abbreviated in business to PV and occasionally called page impression, is a request to load a single HTML file (web page) of an Internet site. On the World Wide Web, a page request would result from a web surfer clicking on a link on another page pointing to the page in question. (Source: [Wikipedia article "Pageviews"](https://en.wikipedia.org/wiki/Pageview))
#
# Pageviews in Wikipedia can tell us that people are looking for certain information online. Analyzing how the volume and the distribution of pageviews changed can tell us about how the behavior of Wikipedia readers has changed.
#
# In this homework, you will take a deep dive into analyzing Wikipedia pageview logs and uncover shifts in interests associated with the current pandemic.
#
# ---
#
# ## The data
#
# First, you need to download a **meraviglioso** dataset from the Italian Wikipedia that we prepared for you. The structure of the data is described next.
#
# **The dataset is available in the `data` directory pushed to the same GitHub repo as the homework**. Inside of the data directory, you will find three files:
#
# ### `articles.tsv.gz`
#
# This is a tab-separated file containing daily pageviews for a subset of the articles from Italian Wikipedia. It is compressed! Each row corresponds to a different article, and each column (except the first) corresponds to the number of pageviews this article received on a given day. The example below shows the structure for two of the things [Kristina Gligorić](https://kristinagligoric.github.io/), one of your TAs, likes the most on her Pizza:
#
# **Example:**
# ~~~
# index       2018-01-01 00:00:00    2018-01-02 00:00:00 (...)
# Formaggio   100                    101                 (...)
# Ananas      12                     54                  (...)
# (...)       (...)                  (...)
# ~~~
#
#
# ### `topics.jsonl.gz`
#
# This is a classification of which topics an article belongs to, according to a model released by the Wikimedia Foundation (the classes are derived from this [taxonomy](https://www.mediawiki.org/wiki/ORES/Articletopic)). Importantly, this file was obtained from English Wikipedia, while the previous one contains articles from the Italian Wikipedia. This is important because article titles in the Italian Wikipedia are in Italian, while article titles in the English page are in English (duh!). In any case, each line contains a .json object with
# the English name of the article (name);
# 1. the English name of the article (`name`);
# 2. a set of fields related to topics themselves. Each of these fields is set as either `True` (if the article belongs to this topic) or `False` (if it does not). Notice that the same article may belong to multiple topics.
#
# **Example:**
# ~~~
# {"index": "Cheese", "Culture.Food and drink": True, "Culture.Literature": False (...)}
# {"index": "Pineapple", "Culture.Food and drink": True, "Culture.Literature": False (...)}
# (...)
# ~~~
#
#
# ### `mapping.pickle`
#
# This is a `.pickle` file, that is, a serialized Python object. You can read about Python pickles  [here](https://wiki.python.org/moin/UsingPickle),
# but in short: the default Python library `pickle` allows you to save and load Python objects to and from disk. This is one object saved via the pickle library: a Python dictionary containing a mapping between the English names and the Italian names of Wikipedia articles:
#
# **Example:**
# ~~~
# {
#     "Cheese": "Formaggio",
#     "Ananas": "Pineapple"
#     (...)
# }
# ~~~
# ---

# %% [markdown]
# ## _Step 1:_ Loading the data
#
# ---
# ### **Task 1**
#
# Your first task is to load all these datasets into memory using pandas and pickle.
# **You should load the files compressed.**
#
# Here, the files at hand are rather small, and you could easily uncompress  the files to disk and work with them as plain text.
# Why, then, are we asking you to load the files compressed? The reason is that, in your life as a data scientist, this will often not be the case.
#
# Then, working with compressed files is key so that you don't receive e-mail from your (often more responsible) colleagues demanding to know how you have managed to fill the entire cluster with your datasets.
# Another big advantage of compressing files is to simply read files faster. You will often find that reading compressed data on the fly (uncompressing it as you go), is much faster than reading compressed data, since reading and writing to the disk may be your [bottleneck](https://skipperkongen.dk/2012/02/28/uncompressed-versus-compressed-read/).
#
#
# ---
#
# **Hint:** `pandas` can open compressed files.
#
# **Hint:** In the real world (and in ADA-homework), your file often comes with some weird lines!
# This time you can safely ignore them (but in the real world you must try to understand why they are there!). Check the `error_bad_lines` parameter on `read_csv`.

# %%
import pandas as pd
import pickle

### ~ 1.1
### Your code here! ###
mapping = pd.read_pickle("data/mapping.pickle")
articles = pd.read_csv("data/articles.tsv.gz", compression="gzip",  header=0, sep='	', error_bad_lines=False)
topics = pd.read_json("data/topics.jsonl.gz", compression="infer", lines=True)
# Out:
# b'Skipping line 7: expected 944 fields, saw 945\n'

# %% [markdown]
# ## _Step 2:_ Filtering the data
#
# ---
# ### **Task 2**
#
# Oh no! Something seems wrong with your dataframe!
# It seems that some of the lines in the `articles.tsv.gz` are weird!
# They have titles in the format `"Discussione:name_of_the_page"`.
#
# Unsure of what they mean, you ask about them in the [Wiki-research mailing list](https://lists.wikimedia.org/mailman/listinfo/wiki-research-l).
# Twenty minutes later a kind internet stranger comes with an answer!
# She tells you that these are talk pages, where people discussing what should and should not be in the article (in fact it can be pretty funny to read, eg, [you can read Italians debating about pizza](https://it.wikipedia.org/wiki/Discussione:Pizza))
#
# After understanding what they are, your task is now to filter these lines using `pandas`! After all, we are interested in pageviews going towards articles! Not discussion pages!
#
# ---
#
# **Hint**: There is one of them in the position \#180 of the dataframe, if you want to check it!

# %%
### ~ 2.1
### Your code here! ###
articles = articles[~articles['index'].astype(str).str.contains('Discussione',case=False)]
articles
# Out:
#                               index  2018-01-01 00:00:00  2018-01-02 00:00:00  \
# 0                            Khulna                    0                    2
# 1                  Karim_Ansarifard                    1                    5
# 2                            Poldhu                    0                    0
# 3      Alice_(The_Sisters_of_Mercy)                    0                    1
# 4                           Palmyra                    1                    4
# ...                             ...                  ...                  ...
# 56786  Metodologia_della_formazione                    1                    8
# 56787                   Metal_Black                    0                    0
# 56788                Tonino_Accolla                   66                   98
# 56789  The_United_States_Steel_Hour                    0                    1
# 56790                 Mauro_Manotas                    1                    0
#
#        2018-01-03 00:00:00  2018-01-04 00:00:00  2018-01-05 00:00:00  \
# 0                        1                    0                    0
# 1                        1                    1                    1
# 2                        1                    1                    0
# 3                        0                    0                    1
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 56786                    8                    9                    4
# 56787                    0                    0                    1
# 56788                   84                   95                   99
# 56789                    4                    0                    0
# 56790                    0                    0                    1
#
#        2018-01-06 00:00:00  2018-01-07 00:00:00  2018-01-08 00:00:00  \
# 0                        2                    0                    2
# 1                        3                    6                    4
# 2                        1                    0                    2
# 3                        1                    1                    1
# 4                        2                   11                    2
# ...                    ...                  ...                  ...
# 56786                    4                    2                    5
# 56787                    0                    0                    0
# 56788                   79                   59                   81
# 56789                    0                    0                    2
# 56790                    0                    0                    0
#
#        2018-01-09 00:00:00  ...  2020-07-22 00:00:00  2020-07-23 00:00:00  \
# 0                        0  ...                    0                    1
# 1                        5  ...                    2                    2
# 2                        2  ...                    0                    2
# 3                        0  ...                    0                    0
# 4                        0  ...                    0                    0
# ...                    ...  ...                  ...                  ...
# 56786                   16  ...                    9                    8
# 56787                    0  ...                    0                    0
# 56788                   77  ...                   43                   40
# 56789                    0  ...                    1                    1
# 56790                    0  ...                    0                    0
#
#        2020-07-24 00:00:00  2020-07-25 00:00:00  2020-07-26 00:00:00  \
# 0                        1                    0                    1
# 1                        0                    1                    2
# 2                        2                    0                    0
# 3                        0                    0                    0
# 4                        1                    0                    0
# ...                    ...                  ...                  ...
# 56786                    7                    7                    2
# 56787                    0                    0                    1
# 56788                   39                   46                   33
# 56789                    2                    0                    0
# 56790                    0                    0                    0
#
#        2020-07-27 00:00:00  2020-07-28 00:00:00  2020-07-29 00:00:00  \
# 0                        1                    0                    2
# 1                        0                    1                    0
# 2                        0                    2                    1
# 3                        1                    0                    0
# 4                        0                    1                    0
# ...                    ...                  ...                  ...
# 56786                   14                    9                    7
# 56787                    1                    1                    0
# 56788                   67                   43                   53
# 56789                    1                    0                    0
# 56790                    0                    0                    1
#
#        2020-07-30 00:00:00  2020-07-31 00:00:00
# 0                        1                    2
# 1                        0                    0
# 2                        2                    1
# 3                        0                    0
# 4                        0                    0
# ...                    ...                  ...
# 56786                    6                    9
# 56787                    0                    0
# 56788                   77                   58
# 56789                    0                    0
# 56790                    0                    1
#
# [55791 rows x 944 columns]

# %% [markdown]
# ## *Step 3*: Understanding the data
#
# ---
# ### **Task 3.1**
# Data cleaning is hard huh? But now that this headache is behind us we can go on to explore our data.
#
# Let's begin with some basic stats. It is always important to do this as a sanity check.
#
# You should:
#
# 1. Start by calculating how many topics and articles there are. Also, while you are at it, print the names of the topics to get a grasp of what they are about.
# 2. Calculate the average daily number of pageviews in the dataset.
# 3. **Discuss:** As previously mentioned, your data is a sample of _some_ (and not all) Wikipedia articles! Estimate (roughly) what percentage of Italian Wikipedia articles are in your dataset comparing your daily average pageview numbers with the official statistics (which can be found [here](https://pageviews.toolforge.org/siteviews/?platform=desktop&source=pageviews&agent=user&start=2020-01-01&end=2020-09-21&sites=it.wikipedia.org)). Notice that we are focusing on the desktop version of Wikipedia.
#
# ---
# **Hint**: topics are in the columns of the topic file!

# %%
### ~ 3.1.1
### Your code here! ###
num_articles = len(articles)
num_topics = len(topics)
topics['index']
# Out:
# 0                      Chinese_food_therapy
# 1                         Battle_of_Naissus
# 2                     Battle_of_Stoke_Field
# 3                               Smooth_newt
# 4                        Vicente_Aleixandre
#                         ...
# 35606                           Banca_Akros
# 35607                       Arms_Around_You
# 35608                     Gioventù_bruciata
# 35609    Power_Rangers:_Battle_for_the_Grid
# 35610          6th_Pioneer_Regiment_(Italy)
# Name: index, Length: 35611, dtype: object

# %%
### ~ 3.1.2
### Your code here! ###
daily_sum = articles.sum(axis=1)
daily_avg = daily_sum.mean()
daily_avg
# Out:
# 5480.891434102275

# %%
### ~ 3.1.3
### Your text (and code if necessary) here! ###
10 percent

# %% [markdown]
# ### **Task 3.2**
#
# Now that we have a better understanding of the data, let's look at some articles to get a feeling of what is happening.
#
# Your task is to:
#
# 1. Find all articles whose names contain the sequence of characters `"virus"` (case insensitive) and that received least 7,000 pageviews across the entire period (no point in zooming on very insignificant articles);
# 2. Find a way to nicely visualize __each__ one of the time-series (in a single plot, which may have multiple panels; in the lecture, Bob referred to these as “small multiples); Your visualization should allow one to see overall trends across each of the different articles and depict the overall trends, with the least noise possible. Additionally, highlight two specific dates in your plot: 31 January ([first case reported in Italy](https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Italy#First_confirmed_cases)) and 21 February ([when multiple cases were confirmed in northern Italy](https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Italy#Clusters_in_northern_Italy)).
# 4. **Discuss**: What did you observe? Did all the articles behave similarly?
#
# ---
#
# **Hint**: The column dates are currently strings which are not very plot friendly. You can turn them into datetime objects using:
#
# ~~~python
# your_dataframe_name.columns = pd.to_datetime(your_dataframe_name.columns)
# ~~~
#
# Notice that this only works if you have only date-related columns. Fortunately, if you get rid of the `index` column by making it a real pandas index, things should work just fine.
#
# **Hint**: Choose your axes wisely!

# %%
### ~ 3.2.1
### Your code here! ###
virus_articles = articles[articles['index'].astype(str).str.contains('virus',case=False)]
virus_articles= virus_articles[virus_articles.sum(axis=1)> 7000]
virus_articles
# Out:
#                                      index  2018-01-01 00:00:00  \
# 5133           Virus_della_leucemia_felina                   11
# 8297               Malattia_da_virus_Ebola                    3
# 12382      Influenzavirus_A_sottotipo_H1N1                   20
# 18385                           Rhinovirus                    6
# 41679                  Virus_(informatica)                   26
# 46472                  Herpesvirus_umano_3                    2
# 54162                            Antivirus                   19
# 56429  Virus_respiratorio_sinciziale_umano                    6
#
#        2018-01-02 00:00:00  2018-01-03 00:00:00  2018-01-04 00:00:00  \
# 5133                    27                   20                   28
# 8297                    21                   13                   23
# 12382                   23                   49                   52
# 18385                    9                   12                   22
# 41679                   70                   74                   66
# 46472                    5                    5                   14
# 54162                   31                   26                   27
# 56429                   11                   18                   18
#
#        2018-01-05 00:00:00  2018-01-06 00:00:00  2018-01-07 00:00:00  \
# 5133                    24                    9                   13
# 8297                    28                    5                   11
# 12382                   46                  108                  271
# 18385                   13                   12                   21
# 41679                   86                   44                   67
# 46472                    6                   13                    9
# 54162                   42                   30                   24
# 56429                   15                   14                    9
#
#        2018-01-08 00:00:00  2018-01-09 00:00:00  ...  2020-07-22 00:00:00  \
# 5133                    36                   30  ...                   13
# 8297                    11                   17  ...                  142
# 12382                  143                   75  ...                   37
# 18385                   18                   19  ...                    8
# 41679                   94                  107  ...                   21
# 46472                   12                   11  ...                   10
# 54162                   54                   45  ...                   16
# 56429                   21                   17  ...                   11
#
#        2020-07-23 00:00:00  2020-07-24 00:00:00  2020-07-25 00:00:00  \
# 5133                    12                   13                    9
# 8297                    30                   25                  126
# 12382                   27                   30                   70
# 18385                   10                   10                   13
# 41679                   38                   21                   18
# 46472                    9                   10                    5
# 54162                   33                   25                   14
# 56429                   10                   10                    4
#
#        2020-07-26 00:00:00  2020-07-27 00:00:00  2020-07-28 00:00:00  \
# 5133                     6                   10                   11
# 8297                    30                   27                  147
# 12382                   36                   39                   39
# 18385                    6                   14                   10
# 41679                   30                   24                   33
# 46472                    7                    8                   13
# 54162                   14                   19                   23
# 56429                    4                    9                    4
#
#        2020-07-29 00:00:00  2020-07-30 00:00:00  2020-07-31 00:00:00
# 5133                     7                    7                    8
# 8297                    25                   39                  146
# 12382                   35                   35                   44
# 18385                    8                    9                   14
# 41679                   28                   22                   17
# 46472                    5                    9                    8
# 54162                   23                   22                   12
# 56429                   12                    5                    7
#
# [8 rows x 944 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,3)) # change this if needed
### ~ 3.2.2
### Your code here! ###
virus_articles_no_ind = virus_articles.drop(['index'], axis=1)
virus_articles_no_ind.columns = pd.to_datetime(virus_articles_no_ind.columns)

fig, axs = plt.subplots(8)
for i in range(8):
    axs[i].plot(virus_articles_no_ind.iloc[i])

plt.xlabel('Date')
plt.ylabel('Articles')
fig.suptitle('Pageviews, trend')
# Out:
# Text(0.5, 0.98, 'Pageviews, trend')

# %%
### ~ 3.2.3
### Your text here! ###
No, some articles are more consistent throughout

# %% [markdown]
# ### **Task 3.3**
#
# Before we move on, let's make a final sanity check and analyze the distribution of pageviews over all articles in our dataset. You are given a function to calculate the **cumulative distribution function** (CDF) of a sample. The CDF is a function f(x) associated with a data sample. For each value x, f(x) represents the percentage of elements in your sample that have values smaller or equal to x (read more about it [here](https://en.wikipedia.org/wiki/Empirical_distribution_function)).
# Your task is to:
#
# 1. Calculate the CDF of the distribution of pageviews across all days over articles. That is, a) calculate the total number of pageviews each article has received and then, b) calculate the CDF for these values.
#
#
# 2. Now plot this function using different scales for the x- and y-axis. You should plot it in 4 different ways:
#
#     a. x-axis on linear scale, y-axis on linear scale
#
#     b. x-axis on log scale, y-axis on linear scale
#
#     c. x-axis on linear scale, y-axis on log scale
#
#     d. x-axis on log scale, y-axis on log scale
#
# 3. **Discuss:** There is a pretty odd fact about the distribution of our data! Can you spot it and describe it? Which of the different plots (a-d) allows you to find this oddity? Why isn't this visible in the other plots?
#
# ---
#
# **Hint:** You can use `plt.xscale` and `plt.yscale`.

# %%
# This function is being given to you with a usage example :)! Make good use!

import numpy as np

def get_cdf(vals):
    # Input:
    # -- vals: an np.array of positive integers
    # Output:
    # -- x: an array containing all numbers from 1 to max(vals);
    # -- y: an array containing the (empirically calculated) probability that vals <= x
    
    y = np.cumsum(np.bincount(vals)[1:])
    y = y / y[-1]
    y = y
    x = list(range(1, max(vals) + 1))
    return x, y  

vals = np.array([1,2,3,4,1,2,4,3,4,4,5,4])
x, y = get_cdf(vals)
plt.plot(x, y)
plt.show()

# %%
### ~ 3.3.1
### Your code here! ###
import numpy as np

def get_cdf(vals):
    # Input:
    # -- vals: an np.array of positive integers
    # Output:
    # -- x: an array containing all numbers from 1 to max(vals);
    # -- y: an array containing the (empirically calculated) probability that vals <= x
    
    y = np.cumsum(np.bincount(vals)[1:])
    y = y / y[-1]
    y = y
    x = list(range(1, max(vals) + 1))
    return x, y  

articles_no_ind = articles.drop(['index'], axis=1)
vals = articles_no_ind.sum(axis=0)
x, y = get_cdf(vals)
plt.plot(x, y)
plt.show()

# %%
### ~ 3.3.2
### Your code here! ###

plt.subplot(411)
plt.plot(x, y)

plt.subplot(412)
plt.plot(x,y)
plt.xscale('symlog')

plt.subplot(413)
plt.plot(x, y)
plt.yscale('symlog')

plt.subplot(414)
plt.plot(x, y)
plt.xscale('symlog')
plt.yscale('symlog')

plt.tight_layout()
plt.show()

# %%
### ~ 3.3.3
### Your text here! ###
b and d show the oddity that the distribution is skewed towards higher ranges of pageviews.

# %% [markdown]
# ## *Step 4*: Analyzing Overall Pageview Volume
#
#
# ---
# ### **Task 4.1**
#
# So far we have seen anecdotal examples. Now let’s move to the big picture! How did Wikipedia pageviews change in general? To gain a better understanding of how Wikipedia’s overall pageview volume has changed during the pandemic, you should do the following:
#
# 1. Calculate and visualize the pageviews trends across summed across **all** articles in Italian Wikipedia for the year 2020. (and only for 2020!).
# 2. **Discuss**: what regular pattern (something that repeats over and over) do you see in the data?
# 3. Pre-process the data to remove this regular pattern and make the overall trend clearer. Repeat the plot with the processed data.
#
# ---
#
# **Hint**: A convenient way to use `.groupby` alongside dates is to use the [`pd.Grouper`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Grouper.html) class. Basically, it allows you to group by date periods given frequencies determined by the parameter `freq`. To read how to specify different types of frequencies, see [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases). Recall that, in order to turn an index, column index -- or pretty much anything -- into a timestamp, you can use  [`pd.to_timestamp`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_timestamp.html).

# %%
plt.figure(figsize=(14,3)) # change this if needed

### ~ 4.1.1
### Your code here! ###
from pandas import Grouper

articles_2020 = articles.iloc[:,'2020-01-01 00:00:00':'2020-07-31 00:00:00']

#groups = daily_sum.groupby(Grouper(freq='A'))
#years = DataFrame()
#for name, group in groups:
    #years[name.year] = group.values
#years.plot(subplots=True, legend=False)
#pyplot.show()
# Out:
# 0         1006
# 1         3332
# 2         1346
# 3          640
# 4          674
#          ...
# 56786     6617
# 56787      578
# 56788    57075
# 56789      669
# 56790      513
# Length: 55791, dtype: int64

# %%
### ~ 4.1.2
### Your text here! ###

# %%
plt.figure(figsize=(14,3)) # change this if needed

### ~ 4.1.3
### Your code here! ###

# %% [markdown]
# ### **Task 4.2**
#
# To get an even clearer picture, your task now is to compare the pageview time series of the current year (2020) with the time series of the previous year (2019).
#
# 1. Make a visualization where the two years are somehow "aligned", that is, where it is possible to compare the same time of year across the two years. Additionally, your visualization should highlight the date on which the nationwide lockdown started in Italy, 9 March 2020. Preprocess each one of the time series (for each year) the same way you did in Task 4.1.
#
# 3. **Discuss:** What changed from 2019 to 2020? Form and justify hypotheses about  the reasons behind this change.
#
# ---
#
# **Hint**: In order to use two different y-axes in the same plot, you can use plt.twiny() or ax.twinx() (the latter if you are using the subplots environment;  [See this example](https://matplotlib.org/3.3.1/gallery/subplots_axes_and_figures/two_scales.html)).

# %%
plt.figure(figsize=(14,3)) # change this if needed

### ~ 4.2.1
## Your code here! ###

# %%
### ~ 4.2.2
### Your text here! ###

# %% [markdown]
# ## *Step 5*: Fiddling with Topics
#
# ---
# ### **Task 5.1**
#
# We now turn to a different question: what topics were impacted by the lockdown?
# To start unpacking this question, your task now is to aggregate, for each day, all pageviews that went to each one of the 64 topics.
#
# There are multiple ways to do this, but for the sake of this exercise, you must create a dataframe where each row contains the number of pageviews a topic obtained on a given day! Example:
#
# ~~~
# index       date                   views
# TOPIC1      2019-01-01             101
# TOPIC1      2019-01-02             151
# (...)       (...)                  (...)
# TOPICK      2019-01-01             1010
# TOPICK      2019-01-02             2123
# (...)       (...)                  (...)
# ~~~
#
# ---
#
# **Hint**: You've should find a way to make the index in the dataframe with the topics be the same as the index in the dataframes with the articles. See the file `mapping.pickle`.
#
# **Hint**: You may want to use `.melt`.

# %%
### ~ 5.1.1
### Your code here! ###
mapping
# Out:
# {'Chinese_food_therapy': 'Dietetica_cinese',
#  'Battle_of_Naissus': 'Battaglia_di_Naisso',
#  'Battle_of_Stoke_Field': 'Battaglia_di_Stoke_Field',
#  'Smooth_newt': 'Lissotriton_vulgaris',
#  'Vicente_Aleixandre': 'Vicente_Aleixandre',
#  'Piast_dynasty': 'Piast',
#  'Antenor': 'Antenore_(scultore)',
#  'Cranford,_New_Jersey': 'Cranford_(New_Jersey)',
#  'New_Castle,_Indiana': 'New_Castle_(Indiana)',
#  'Bugsy': 'Bugsy',
#  'Period_6_element': 'Elementi_del_periodo_6',
#  'Kite_aerial_photography': "Foto_aerea_con_l'aquilone",
#  'World_Economic_Forum': 'Forum_economico_mondiale',
#  'Gherman_Titov': 'German_Stepanovič_Titov',
#  'Vicarius_Filii_Dei': 'Vicarius_Filii_Dei',
#  'SMS_Zrínyi': 'SMS_Zrinyi',
#  "Spearman's_rank_correlation_coefficient": 'Coefficiente_di_correlazione_per_ranghi_di_Spearman',
#  'Swedish_nobility': 'Nobiltà_svedese',
#  'Derrick_Green': 'Derrick_Green',
#  'A._Merritt': 'Abraham_Merritt',
#  'Lee_Chang-dong': 'Lee_Chang-dong',
#  'Shimabara,_Nagasaki': 'Shimabara',
#  'George_Mundelein': 'George_William_Mundelein',
#  'Miramare_Castle': 'Castello_di_Miramare',
#  'Yuki_Kajiura': 'Yuki_Kajiura',
#  'Teheran_43': 'Nido_di_spie',
#  'Optimal_control': 'Controllo_ottimo',
#  "Presidents'_Trophy": "Presidents'_Trophy",
#  'Cupedidae': 'Cupedidae',
#  'Blue_Ridge_Mountains': 'Monti_Blue_Ridge',
#  'Jacques_Rivette': 'Jacques_Rivette',
#  'Emiko_Shiratori': 'Emiko_Shiratori',
#  'Theatre_Royal_Haymarket': 'Haymarket_Theatre',
#  'String_Quartet_No._11_(Beethoven)': 'Quartetto_n._11_(Beethoven)',
#  'Billy_Bremner': 'Billy_Bremner',
#  'Raven-Symoné': 'Raven-Symoné',
#  '2001_World_Championships_in_Athletics': 'Campionati_del_mondo_di_atletica_leggera_2001',
#  'Subrata_Roy': 'Subrata_Roy',
#  'Ritonavir': 'Ritonavir',
#  'Pilatus_PC-21': 'Pilatus_PC-21',
#  'Embryonic': 'Embryonic',
#  'Out_of_Our_Heads': 'Out_of_Our_Heads',
#  'Larry_Beinhart': 'Larry_Beinhart',
#  'She_Loves_Me': 'She_Loves_Me',
#  '1999_Spanish_Grand_Prix': 'Gran_Premio_di_Spagna_1999',
#  'Jaromír_Nohavica': 'Jaromír_Nohavica',
#  'Enantiornithes': 'Enantiornithes',
#  'Pandora_Archive': 'PANDORA',
#  'Kaleidoscope_(Kelis_album)': 'Kaleidoscope_(Kelis)',
#  'Andreas_Divus': 'Andrea_Divo_di_Capodistria',
#  'Serbian_art': 'Arte_serba',
#  'Robert_Horry': 'Robert_Horry',
#  'Antonio_Vivarini': 'Antonio_Vivarini',
#  'Return_to_Never_Land': "Ritorno_all'Isola_che_non_c'è",
#  'Chifeng': 'Chifeng',
#  'John_Henry_Holland': 'John_Henry_Holland',
#  'Darvel': 'Darvel',
#  'Santa_Maria_in_Trastevere': 'Basilica_di_Santa_Maria_in_Trastevere',
#  'Roman_Catholic_Diocese_of_Westminster': 'Arcidiocesi_di_Westminster',
#  'Philippe_Garrel': 'Philippe_Garrel',
#  "Brenda's_Got_a_Baby": "Brenda's_Got_a_Baby",
#  'Colle_System': 'Sistema_Colle',
#  'Antigua': 'Antigua_(isola)',
#  'The_Naked_City': 'La_città_nuda',
#  'Yeshe_Tsogyal': 'Yeshe_Tsogyal',
#  "Gettin'_Jiggy_wit_It": "Gettin'_Jiggy_Wit_It",
#  'Process_(anatomy)': 'Apofisi',
#  'Taras_Bulba': "Taras_Bul'ba",
#  'Bardaisan': 'Bardesane',
#  'The_Saga_of_Darren_Shan': 'Saga_di_Darren_Shan',
#  'Publius_Licinius_Crassus_Dives_Mucianus': 'Publio_Licinio_Crasso_Dive_Muciano',
#  'AGM-123_Skipper_II': 'AGM-123_Skipper_II',
#  'Mediterranean_Basin': 'Bacino_del_Mediterraneo',
#  'Esophageal_rupture': 'Sindrome_di_Boerhaave',
#  'Mark_Isham': 'Mark_Isham',
#  'Franco_Saudelli': 'Franco_Saudelli',
#  'Karen_Dior': 'Karen_Dior',
#  'EAR_(file_format)': 'EAR_(formato_di_file)',
#  'Hawkins_(TV_series)': 'Hawkins_(serie_televisiva)',
#  'Eddie_and_the_Cruisers': 'La_banda_di_Eddie',
#  'Brontosaurus': 'Brontosaurus',
#  "José_Saenz_d'Aguirre": 'José_Aguirre',
#  'Liz_White_(actress)': 'Liz_White',
#  'Electronic_tuner': 'Accordatore_(musica)',
#  'DBRS': 'DBRS',
#  'Marcus_Roscius_Coelius': 'Marco_Roscio_Celio',
#  'Erich_Rothacker': 'Erich_Rothacker',
#  'Precious_Time_(album)': 'Precious_Time',
#  'Church_of_Our_Lady_Victorious': 'Chiesa_di_Santa_Maria_della_Vittoria_(Praga)',
#  'San_Potito_Ultra': 'San_Potito_Ultra',
#  'Stephen_McHattie': 'Stephen_McHattie',
#  'Wrestling_at_the_1960_Summer_Olympics': 'Lotta_ai_Giochi_della_XVII_Olimpiade',
#  'Vaglio_Serra': 'Vaglio_Serra',
#  'Carobbio_degli_Angeli': 'Carobbio_degli_Angeli',
#  'Phenylacetylene': 'Fenilacetilene',
#  'Pognana_Lario': 'Pognana_Lario',
#  'Rizzo_(surname)': 'Rizzo_(cognome)',
#  'Charles_Antenen': 'Charles_Antenen',
#  'Sergius_Orata': 'Gaio_Sergio_Orata',
#  'Ginan_(star)': 'Epsilon_Crucis',
#  'Arenella': 'Arenella_(Napoli)',
#  'Christian_Gyan': 'Christian_Gyan',
#  'Nymphidius_Sabinus': 'Ninfidio_Sabino',
#  'MySims': 'MySims',
#  'Yordi': 'Yordi',
#  'Bison_latifrons': 'Bison_latifrons',
#  'Raymonda': 'Raymonda',
#  'Francisco_José_de_Caldas': 'Francisco_José_de_Caldas',
#  'Wilfred_Agbonavbare': 'Wilfred_Agbonavbare',
#  'Crystal_Palace_F.C._(1861)': 'Crystal_Palace_Football_Club_(1861)',
#  'Hydroxyprogesterone_caproate': 'Idrossiprogesterone_caproato',
#  'Clustered_file_system': 'Clustered_file_system',
#  'Patrick_Patterson_(basketball)': 'Patrick_Patterson',
#  'Sébastien_Buemi': 'Sébastien_Buemi',
#  'Elijah_Kelley': 'Elijah_Kelley',
#  'Imperial_Sword': 'Spada_Imperiale',
#  'Skulptur_Projekte_Münster': 'Skulptur_Projekte',
#  'Richard_McCabe': 'Richard_McCabe',
#  'Lune_(geometry)': 'Lunula_(matematica)',
#  'Suvi_Koponen': 'Suvi_Koponen',
#  'Andrea_Checchi': 'Andrea_Checchi',
#  'Goosebumps_HorrorLand': 'Horrorland',
#  'Wiener_Melange': 'Melange_Viennese',
#  "Charlie_Chan's_Secret": "L'ora_che_uccide_(film_1936)",
#  'Larche,_Alpes-de-Haute-Provence': "Larche_(Alpi_dell'Alta_Provenza)",
#  'Niklas_Axelsson': 'Niklas_Axelsson',
#  'Harley-Davidson_VRSC': 'Harley-Davidson_V-Rod',
#  'Sopressa': 'Sopressa_Vicentina',
#  'Order_of_Theresa': 'Ordine_di_Teresa',
#  'Yankee_(film)': 'Yankee_(film)',
#  'Jeroen_Verhoeven': 'Jeroen_Verhoeven',
#  'Lend_Me_Your_Comb': 'Lend_Me_Your_Comb',
#  'Colegiata_de_San_Isidro,_Madrid': "Collegiata_di_Sant'Isidoro",
#  'J/80': 'J/80',
#  'Halloween_with_the_New_Addams_Family': 'Halloween_con_la_famiglia_Addams',
#  'Kyle_Landry': 'Kyle_Landry',
#  'Rodrigo_Alborno': 'Rodrigo_Alborno',
#  '1976_Intercontinental_Cup': 'Coppa_Intercontinentale_1976',
#  'Cesare_Facchinetti': 'Cesare_Facchinetti',
#  'Frida_Kahlo_Museum': 'Museo_Frida_Kahlo',
#  'Opta_Sports': 'Opta',
#  'Siege_of_Crema': 'Assedio_di_Crema',
#  "Marilyn_Monroe's_pink_dress": 'Vestito_rosa_di_Marilyn_Monroe',
#  'Kimi_to_Boku_(manga)': 'Kimi_to_boku',
#  '11.22.63': '22.11.63',
#  'Salaiola': 'Salaiola',
#  'From_Death_to_Destiny': 'From_Death_to_Destiny',
#  'Eimear_McBride': 'Eimear_McBride',
#  'Eden_Ben_Zaken': 'Eden_Ben_Zaken',
#  'Riccardo_Gagliolo': 'Riccardo_Gagliolo',
#  'Trinitapoli-San_Ferdinando_di_Puglia_railway_station': 'Stazione_di_Trinitapoli-San_Ferdinando_di_Puglia',
#  'From_Morn_to_Midnight': 'Von_morgens_bis_mitternachts',
#  'Donatella_(group)': 'Donatella_(gruppo_musicale)',
#  '2016_Beninese_presidential_election': 'Elezioni_presidenziali_in_Benin_del_2016',
#  'Kasey_Palmer': 'Kasey_Palmer',
#  'Mimmi_Larsson': 'Mimmi_Larsson',
#  'Phryne_before_the_Areopagus': "Frine_davanti_all'Areopago",
#  'The_Seventh_Room': 'La_settima_stanza',
#  'HCSS_(album)': 'HCSS',
#  'TB/FC_Suðuroy/Royn': 'Tvøroyrar_Bóltfelag/Football_Club_Suðuroy/Royn_Hvalba',
#  'Chicago_P.D._(season_5)': 'Episodi_di_Chicago_P.D._(quinta_stagione)',
#  'Camille_Barrère': 'Camille_Barrère',
#  'Mercedes-Benz_M152_engine': 'Mercedes-Benz_M152',
#  '101_Dalmatian_Street': '101_Dalmatian_Street',
#  'Giacomo_van_Lint': 'Giacomo_Van_Lint',
#  'Metallic_bonding': 'Legame_metallico',
#  'The_Resistible_Rise_of_Arturo_Ui': 'La_resistibile_ascesa_di_Arturo_Ui',
#  'Geologic_time_scale': 'Scala_dei_tempi_geologici',
#  'Iceland': 'Islanda',
#  'History_of_Spain': 'Storia_della_Spagna',
#  '375': '375',
#  'Vapor_pressure': 'Pressione_di_vapore',
#  'Plumstead': 'Plumstead',
#  'London_Borough_of_Southwark': 'Southwark_(borgo_di_Londra)',
#  'Gyges_of_Lydia': 'Gige_(Lidia)',
#  'Dorothy_Tutin': 'Dorothy_Tutin',
#  'Paul-Henri_Spaak': 'Paul-Henri_Spaak',
#  'G-funk': 'G-funk',
#  'Oliver_Twist': 'Oliver_Twist',
#  'Ronald_McNair': 'Ronald_McNair',
#  'Static_electricity': 'Elettricità_statica',
#  'Siege_of_Kut': 'Assedio_di_Kut',
#  'Sputum': 'Espettorato',
#  'Salyut_7': 'Saljut_7',
#  'Reichenau,_Switzerland': 'Reichenau_(Tamins)',
#  'Planxty': 'Planxty',
#  'Iron_lung': "Polmone_d'acciaio",
#  'Tank_locomotive': 'Locomotiva-tender',
#  'Archery_at_the_1988_Summer_Olympics': "Tiro_con_l'arco_ai_Giochi_della_XXIV_Olimpiade",
#  'Societal_attitudes_toward_homosexuality': "Atteggiamenti_sociali_nei_confronti_dell'omosessualità",
#  'Edgar_Wallace': 'Edgar_Wallace',
#  'Don_Messick': 'Don_Messick',
#  'Mount_Karisimbi': 'Karisimbi',
#  'Battle_of_Loos': 'Battaglia_di_Loos',
#  'Extended_Unix_Code': 'Extended_Unix_Code',
#  'Chromoplast': 'Cromoplasto',
#  'Matching_(graph_theory)': 'Accoppiamento_(teoria_dei_grafi)',
#  'Dean_Cain': 'Dean_Cain',
#  'Ma_Zhiyuan': 'Ma_Zhiyuan',
#  'Kazimierz_Bartel': 'Kazimierz_Bartel',
#  'Trainz': 'Trainz',
#  'Jessica_Biel': 'Jessica_Biel',
#  'Kij_Johnson': 'Kij_Johnson',
#  'Great_Western_Railway_(train_operating_company)': 'Great_Western_Railway_(operatore_ferroviario)',
#  'Human_Head_Studios': 'Human_Head_Studios',
#  'Howard_Rollins': 'Howard_Rollins',
#  'Mighty_Like_a_Rose': 'Mighty_Like_a_Rose',
#  'Early_modern_warfare': 'Uso_bellico_della_polvere_da_sparo',
#  'Kimberly_Goss': 'Kimberly_Goss',
#  'BMW_M1': 'BMW_M1',
#  'Shōgun_(1980_miniseries)': 'Shōgun_(miniserie_televisiva)',
#  'Condor_(Argentine_missile)': 'Condor_(missile)',
#  'Bob_Gerard': 'Bob_Gerard',
#  'Transvision_Vamp': 'Transvision_Vamp',
#  'Andrés_Avelino_Cáceres': 'Andrés_Avelino_Cáceres',
#  'Equilibrium_point': 'Punto_di_equilibrio',
#  'Versatile_(company)': 'Versatile',
#  'Ketubah': 'Ketubah',
#  'Symphony_No._7_(Sibelius)': 'Sinfonia_n._7_(Sibelius)',
#  'The_Timberland_Company': 'Timberland',
#  'Colour_revolution': 'Rivoluzioni_colorate',
#  "Bryan_Lee_O'Malley": "Bryan_Lee_O'Malley",
#  'Calcium_nitrate': 'Nitrato_di_calcio',
#  'Let_Love_Lead_the_Way': 'Let_Love_Lead_the_Way',
#  'Aquilegia_coerulea': 'Aquilegia_caerulea',
#  'Architecture_of_Windows_NT': 'Architettura_Windows_NT',
#  'Jerk_It_Out': 'Jerk_It_Out',
#  'Pedro_de_Sintra': 'Pedro_da_Sintra',
#  'Tony_Chimel': 'Tony_Chimel',
#  'Huaihua': 'Huaihua',
#  'Tamera_Mowry': 'Tamera_Mowry',
#  'Kelly_Tripucka': 'Kelly_Tripucka',
#  'Udbina': 'Udbina',
#  '1985_Swedish_general_election': 'Elezioni_legislative_in_Svezia_del_1985',
#  'Rogerius_(physician)': 'Rogerio_Frugardi',
#  'Doctor_Sax': 'Il_dottor_Sax',
#  'Nottuln': 'Nottuln',
#  'Žydrūnas_Karčemarskas': 'Žydrūnas_Karčemarskas',
#  'European_route_E39': 'Strada_europea_E39',
#  'Tomioka_Silk_Mill': 'Mulino_da_seta_di_Tomioka',
#  'Brain_Donors': 'Gli_sgangheroni',
#  'Ricardo_Oliveira': 'Ricardo_Oliveira',
#  'Languages_of_Spain': 'Lingue_della_Spagna',
#  'Italian_Hours': 'Ore_italiane',
#  'David_Brandt_(American_football)': 'David_Brandt',
#  'Boxer_at_Rest': 'Pugile_in_riposo',
#  'Inertial_switch': 'Interruttore_inerziale',
#  'DeSoto_Diplomat': 'DeSoto_Diplomat',
#  "I'm_the_Man_(album)": "I'm_the_Man_(Joe_Jackson)",
#  'Parliament_House,_Helsinki': 'Palazzo_del_Parlamento_finlandese',
#  'Titus_Brandsma': 'Tito_Brandsma',
#  '2006–07_UEFA_Champions_League': 'UEFA_Champions_League_2006-2007',
#  'The_Black_Stallion': 'The_Black_Stallion',
#  'Family_Guy_Video_Game!': 'Family_Guy_Video_Game!',
#  'Khordha': 'Khordha',
#  'Teenage_Caveman_(1958_film)': 'Adolescente_delle_caverne',
#  'Murder_on_the_Orient_Express_(2001_film)': "Assassinio_sull'Orient_Express_(film_2001)",
#  'Tiberius_Sempronius_Longus_(consul_194_BC)': 'Tiberio_Sempronio_Longo_(console_194_a.C.)',
#  'Quark-nova': 'Quark-nova',
#  'Jacques-François_Menou': 'Jacques_François_Menou',
#  "Jean_d'Orléans-Longueville": "Jean_d'Orléans-Longueville",
#  'Beta-Hydroxybutyric_acid': 'Acido_β-idrossibutirrico',
#  'Stan_Lee_Media': 'Stan_Lee_Media',
#  'Smear_Campaign_(album)': 'Smear_Campaign',
#  'Isaac_Gálvez': 'Isaac_Gálvez',
#  'Word_of_Mouth_(The_Kinks_album)': 'Word_of_Mouth_(The_Kinks)',
#  'Popillia_(gens)': 'Gens_Popillia',
#  'Zell_im_Wiesental': 'Zell_im_Wiesental',
#  'Harry_Ackerman': 'Harry_Ackerman',
#  'San_Cesario_di_Lecce': 'San_Cesario_di_Lecce',
#  'Fahad_Al-Ahmed_Al-Jaber_Al-Sabah': 'Fahad_Al-Ahmed_Al-Jaber_Al-Sabah',
#  'Ludwig_Lichtheim': 'Ludwig_Lichtheim',
#  'Titus_Didius': 'Tito_Didio',
#  'Soft_Heap': 'Soft_Heap',
#  '1._FFC_Frankfurt': '1._Frauen-Fußball-Club_Frankfurt',
#  'Orgeval,_Yvelines': 'Orgeval_(Yvelines)',
#  'Pergamus': 'Pergamo_(mitologia)',
#  'Edwin_Cerio': 'Edwin_Cerio',
#  'Hernán_Cristante': 'Hernán_Cristante',
#  'Prosper_of_Reggio': 'Prospero_di_Reggio_Emilia',
#  'Year_of_the_Dog_(film)': 'Year_of_the_Dog_(film)',
#  'Free_State_of_Mecklenburg-Strelitz': 'Libero_Stato_di_Meclemburgo-Strelitz',
#  'Munich-Riem_Airport': 'Aeroporto_di_Monaco-Riem',
#  'Horst_Heldt': 'Horst_Heldt',
#  'Dubrovnik_Cathedral': "Cattedrale_dell'Assunzione_di_Maria_(Ragusa,_Croazia)",
#  'Hugo_of_Santalla': 'Ugo_di_Santalla',
#  'Conrad_Goode': 'Conrad_Goode',
#  'José_Salomón': 'José_Salomón',
#  'The_Bourne_Ultimatum': 'Il_ritorno_dello_sciacallo',
#  'Citarum_River': 'Citarum',
#  "Vissi_d'arte": "Vissi_d'arte",
#  '1389_papal_conclave': 'Conclave_del_1389',
#  'Bi-2': 'Bi-2',
#  'Alban_Hoxha': 'Alban_Hoxha',
#  'Luca_di_Tommè': 'Luca_di_Tommè',
#  'Liutperga': 'Liutperga',
#  'Enrique_Gorostieta': 'Enrique_Gorostieta_Velarde',
#  'Guitar_Hero_Mobile_series': 'Guitar_Hero_III_Mobile',
#  'European_Hockey_Federation': 'European_Hockey_Federation',
#  'Roman_Catholic_Diocese_of_Chioggia': 'Diocesi_di_Chioggia',
#  'Lolita_Lempicka': 'Lolita_Lempicka',
#  'Girolamo_Benzoni': 'Girolamo_Benzoni',
#  'Nataša_Krsmanović': 'Nataša_Krsmanović',
#  "The_Devil's_Daughter_(1915_film)": "The_Devil's_Daughter",
#  'Sehnsucht': 'Sehnsucht_(romanticismo)',
#  'Carlo_Vanzina': 'Carlo_Vanzina',
#  'Un_giorno_nella_vita': 'Un_giorno_nella_vita_(film_1946)',
#  'Messenger_of_Death': 'Messaggio_di_morte',
#  'Perché_non_torna_più': 'Perché_non_torna_più',
#  'Zaïre_(play)': 'Zaira_(Voltaire)',
#  'Hillary_Scott': 'Hillary_Scott_(cantante)',
#  '1961_World_Fencing_Championships': 'Campionato_mondiale_di_scherma_1961',
#  'Aurelia_(name)': 'Aurelia_(nome)',
#  'Sexting': 'Sexting',
#  'Tefik_Mborja': 'Tefik_Mborja',
#  'Justinian_(general)': 'Giustiniano_(generale)',
#  'Luigi_Rizzi_(footballer)': 'Luigi_Rizzi_(calciatore)',
#  'Ajmalicine': 'Raubasina',
#  'Will_&_Grace_(season_8)': 'Episodi_di_Will_&_Grace_(ottava_stagione)',
#  'Gary_Low': 'Gary_Low',
#  'John_Morosini': 'Giovanni_Morosini',
#  'LibreOffice_Calc': 'LibreOffice_Calc',
#  'Goldene_Leinwand': 'Goldene_Leinwand',
#  "It's_Getting_Later_All_the_Time": 'Si_sta_facendo_sempre_più_tardi',
#  'Zwevezele': 'Zwevezele',
#  'Body_of_Proof_(season_3)': 'Episodi_di_Body_of_Proof_(terza_stagione)',
#  'Aleksandr_Nedovyesov': 'Oleksandr_Nedovjesov',
#  'Orlando_Polmonari': 'Orlando_Polmonari',
#  'Renata_Notni': 'Renata_Notni',
#  'Meddie_Kagere': 'Meddie_Kagere',
#  'Luiza_Gega': 'Luiza_Gega',
#  '2013–14_Coupe_de_la_Ligue': 'Coupe_de_la_Ligue_2013-2014',
#  'Pastila': 'Pastilà',
#  'Alfredo_Aguilar': 'Alfredo_Aguilar',
#  'Valerian_Gvilia': 'Valerian_Gvilia',
#  "Annali_dell'Istituto_Superiore_di_Sanità": "Annali_dell'Istituto_superiore_di_sanità",
#  'Hannah_Hoekstra': 'Hannah_Hoekstra',
#  'Lexa_(singer)': 'Lexa_(cantante)',
#  '2014–15_Stade_Malherbe_Caen_season': 'Stade_Malherbe_Caen_Calvados_Basse-Normandie_2014-2015',
#  'Christian_Pfister': 'Christian_Pfister',
#  'Counterfeit_(band)': 'Counterfeit_(gruppo_musicale)',
#  'Pierino_medico_della_Saub': 'Pierino_medico_della_SAUB',
#  "Santini's_Network": 'La_rete_di_Santini',
#  'La_Popolarissima': 'La_Popolarissima',
#  'Madame_Hyde': 'Madame_Hyde',
#  'Psych:_The_Movie': 'Psych:_The_Movie',
#  'La_dama_boba_(opera)': 'La_dama_boba',
#  'Zehra_Doğan': 'Zehra_Doğan',
#  'Illang:_The_Wolf_Brigade': 'Illang_-_Uomini_e_lupi',
#  'Chicago_P.D._(season_6)': 'Episodi_di_Chicago_P.D._(sesta_stagione)',
#  'Khabarovsk_railway_station': 'Stazione_di_Chabarovsk_1',
#  'Money_(Cardi_B_song)': 'Money_(Cardi_B)',
#  'Giuseppe_Maria_Giovene': 'Giuseppe_Maria_Giovene',
#  'Home_(Kobi_Marimi_song)': 'Home_(Kobi_Marimi)',
#  'Cauchy–Riemann_equations': 'Equazioni_di_Cauchy-Riemann',
#  'Grammatical_gender': 'Genere_(linguistica)',
#  'Money_laundering': 'Riciclaggio_di_denaro',
#  '1256': '1256',
#  'Heinrich_Zschokke': 'Johann_Heinrich_David_Zschokke',
#  '237_BC': '237_a.C.',
#  'X.500': 'X.500',
#  'Formentera': 'Formentera',
#  'Wodonga': 'Wodonga',
#  'Atlas_(anatomy)': 'Atlante_(anatomia)',
#  'United_States_Department_of_Health_and_Human_Services': "Dipartimento_della_salute_e_dei_servizi_umani_degli_Stati_Uniti_d'America",
#  'Chemical_warfare': 'Guerra_chimica',
#  'Gullveig': 'Gullveig',
#  'William_Stokoe': 'William_Stokoe',
#  'Manfred_von_Richthofen': 'Manfred_von_Richthofen',
#  'Clinton,_Iowa': 'Clinton_(Iowa)',
#  'Guy_of_Lusignan': 'Guido_di_Lusignano',
#  'Henry_VI,_Part_1': 'Enrico_VI,_parte_I',
#  'Parity_bit': 'Bit_di_parità',
#  'Religious_persecution': 'Persecuzione_religiosa',
#  'Phenylalanine_hydroxylase': 'Fenilalanina_4-monoossigenasi',
#  'François_Rude': 'François_Rude',
#  'Stellar_population': 'Popolazioni_stellari',
#  'Guido_Cantelli': 'Guido_Cantelli',
#  'Alexis_Piron': 'Alexis_Piron',
#  'Pythagoreanism': 'Scuola_pitagorica',
#  'Ashurbanipal': 'Assurbanipal',
#  'Electrical_efficiency': 'Rendimento_(elettrotecnica)',
#  'Korteweg–de_Vries_equation': 'Equazione_di_Korteweg-de_Vries',
#  'Dublin_Bay': 'Baia_di_Dublino',
#  'Lucas_number': 'Successione_di_Lucas',
#  'Kotayk_Province': "Provincia_di_Kotayk'",
#  'Dick_Van_Dyke': 'Dick_Van_Dyke',
#  'Nuristan_Province': 'Nurestan',
#  'Tahirid_dynasty': 'Tahiridi',
#  'Clare_Hall,_Cambridge': 'Clare_Hall',
#  'Stripes_(film)': 'Stripes_-_Un_plotone_di_svitati',
#  'Institute_of_Contemporary_Arts': 'Institute_of_Contemporary_Arts',
#  'Martin_Lister': 'Martin_Lister',
#  'Henry_FitzRoy,_Duke_of_Richmond_and_Somerset': 'Henry_FitzRoy,_I_duca_di_Richmond_e_Somerset',
#  'Philippe_Perrin': 'Philippe_Perrin',
#  'MTV_Select': 'MTV_Select',
#  'France_2': 'France_2',
#  'Diving_at_the_2000_Summer_Olympics': 'Tuffi_ai_Giochi_della_XXVII_Olimpiade',
#  'Catholic_Archdiocese_of_Chicago': 'Arcidiocesi_di_Chicago',
#  'Propyne': 'Propino',
#  'Cisapride': 'Cisapride',
#  'Cognizant': 'Cognizant',
#  'Eugène_Fromentin': 'Eugène_Fromentin',
#  'Methone_(moon)': 'Metone_(astronomia)',
#  'Grand_Bahama': 'Grand_Bahama',
#  'Ann_Rule': 'Ann_Rule',
#  'Angara_(rocket_family)': 'Famiglia_di_lanciatori_Angara',
#  'CYP2D6': 'CYP2D6',
#  'Grażyna_Bacewicz': 'Grażyna_Bacewicz',
#  'Nándor_Hidegkuti': 'Nándor_Hidegkuti',
#  'Ileus': 'Ileo_(patologia)',
#  'Tartuffe': 'Il_Tartuffo',
#  'Protection_(Massive_Attack_album)': 'Protection_(album_Massive_Attack)',
#  'Hatfield_and_the_North': 'Hatfield_and_the_North',
#  'Scone_Palace': 'Palazzo_di_Scone',
#  "Dante's_Inferno_(1935_film)": 'La_nave_di_Satana',
#  'Ernie_Roth': 'Ernie_Roth',
#  'Posterior_Analytics': 'Analitici_secondi',
#  'A_Moment_Like_This': 'A_Moment_Like_This',
#  'Mercedes-Benz_S-Class_(W220)': 'Mercedes-Benz_W220',
#  'Duchy_of_Estonia_(1219–1346)': 'Ducato_di_Estonia',
#  'Toxicity_(song)': 'Toxicity_(singolo)',
#  'Perdition_City': 'Perdition_City',
#  'Mondello_Park': 'Mondello_Park',
#  'Arator': 'Aratore',
#  '1978_NBA_draft': 'Draft_NBA_1978',
#  'Blinx:_The_Time_Sweeper': 'Blinx:_The_Time_Sweeper',
#  'Battle_of_Groix': 'Battaglia_di_Groix',
#  'Telluric_acid': 'Acido_tellurico',
#  'Pierre_François_Marie_Auguste_Dejean': 'Pierre_François_Dejean',
#  'Balkan_Pact': 'Intesa_balcanica',
#  'William_Lee_Scott': 'William_Lee_Scott',
#  'Hella_Good': 'Hella_Good',
#  'Joseph_Ludwig_Raabe': 'Joseph_Ludwig_Raabe',
#  'Lucky_(In_My_Life)': 'Lucky_(In_My_Life)',
#  'Dana_Barros': 'Dana_Barros',
#  '2N3055': '2N3055',
#  "I'm_Lovin'_It_(song)": "I'm_Lovin'_It",
#  'Manoeuvring_thruster': 'Elica_di_manovra',
#  'Ajmer_district': 'Distretto_di_Ajmer',
#  'Park_Royal': 'Park_Royal',
#  'Parminder_Nagra': 'Parminder_Nagra',
#  'Pilot_(My_Name_Is_Earl)': 'La_lista_di_Earl',
#  'Tubthumping': 'Tubthumping',
#  'Bruno_Pelletier': 'Bruno_Pelletier',
#  'SketchUp': 'SketchUp',
#  'Neftekamsk': 'Neftekamsk',
#  'Church_of_Saint_George,_Sofia': 'Chiesa_di_San_Giorgio_(Sofia)',
#  '7066_Nessus': '7066_Nessus',
#  'Debi_Mae_West': 'Debi_Mae_West',
#  'Bryan_Nesbitt': 'Bryan_Nesbitt',
#  'Surge_(glacier)': 'Surge_glaciale',
#  'Franz_Xaver_Richter': 'Franz_Xaver_Richter',
#  'Oriental_riff': 'Tema_stereotipo_della_musica_cinese',
#  'Rhapsody_of_the_Seas': 'Rhapsody_of_the_Seas',
#  'Winogradsky_column': 'Colonna_di_Vinogradskij',
#  'Robin_Li': 'Robin_Li',
#  'Maria_of_Jülich-Berg': 'Maria_di_Jülich-Berg',
#  'Take_the_Long_Way_Home_(Supertramp_song)': 'Take_the_Long_Way_Home',
#  'Liverpool_Central_Library': 'Biblioteca_centrale_di_Liverpool',
#  'Sicilian_Mafia_Commission': 'Commissione_provinciale',
#  'Tim_Wilkison': 'Tim_Wilkison',
#  'Fauja_Singh': 'Fauja_Singh',
#  'Enrique_Ballestrero': 'Enrique_Ballesteros',
#  "Francesco_de'_Pazzi": "Francesco_de'_Pazzi",
#  'Trimethylphosphine': 'Trimetilfosfina',
#  'Richard_Marx_(album)': 'Richard_Marx_(album)',
#  'Inorganic_pyrophosphatase': 'Pirofosfatasi_inorganica',
#  'Enrofloxacin': 'Enrofloxacina',
#  'Benedetto_Gennari': 'Benedetto_Gennari_senior',
#  'Naked_Tango': 'Tango_nudo',
#  'Lucilius_Bassus': 'Sesto_Lucilio_Basso',
#  'Beautiful_Noise': 'Beautiful_Noise',
#  'Mario_Pezzi_(aviator)': 'Mario_Pezzi_(aviatore)',
#  'Sir_Francis_Fletcher-Vane,_5th_Baronet': 'Francis_Vane',
#  'Teddy_Newton': 'Teddy_Newton',
#  'Luisa_of_Naples_and_Sicily': 'Luisa_Maria_Amalia_di_Borbone-Napoli',
#  'Ginger_and_Cinnamon': 'Dillo_con_parole_mie',
#  'Distributed_search_engine': 'Motore_di_ricerca_distribuito',
#  'Ginsenoside': 'Ginsenoside',
#  'Pietro_Caruso': 'Pietro_Caruso',
#  'Antonis_Petropoulos': 'Antōnīs_Petropoulos',
#  'Kanafeh': 'Kanafeh',
#  'Macedonian_First_League_(basketball)': 'Makedonska_prva_liga',
#  'Georg_Christian_Adler': 'Georg_Christian_Adler',
#  'Sodium_tetraphenylborate': 'Tetrafenilborato_di_sodio',
#  '1989_Copa_Libertadores': 'Coppa_Libertadores_1989',
#  'Lamine_Diack': 'Lamine_Diack',
#  'Yana_Toboso': 'Yana_Toboso',
#  'Sloan_Privat': 'Sloan_Privat',
#  'Half-elf_(Dungeons_&_Dragons)': 'Mezzelfo_(Dungeons_&_Dragons)',
#  'European_Geoparks_Network': 'European_Geopark',
#  'Phylica_arborea': 'Phylica_arborea',
#  'The_General_of_the_Dead_Army_(film)': "Il_generale_dell'armata_morta_(film)",
#  'Orel_(spacecraft)': 'Federacija_(veicolo_spaziale)',
#  'Phalaenopsis_bellina': 'Phalaenopsis_bellina',
#  'Man_Without_a_Star': "L'uomo_senza_paura",
#  'Dread_(film)': 'Dread',
#  'The_Swingle_Singers_discography': 'Discografia_di_The_Swingle_Singers',
#  'Bjerrum_plot': 'Diagramma_di_Bjerrum',
#  'Hiberno-Roman_relations': 'Hibernia_e_impero_romano',
#  'Mega_Shark_Versus_Crocosaurus': 'Mega_Shark_Versus_Crocosaurus',
#  'The_Edge_of_Glory': 'The_Edge_of_Glory',
#  'European_Union_Prize_for_Literature': "Premio_letterario_dell'Unione_europea",
#  'Undercover_(Bulgarian_TV_series)': 'Undercover_(serie_televisiva)',
#  'Revoltella_Museum': 'Museo_Revoltella',
#  'Brickleberry': 'Brickleberry',
#  'Nima_Nourizadeh': 'Nima_Nourizadeh',
#  'Showmatch': 'Showmatch',
#  'Diffuse_intrinsic_pontine_glioma': 'Glioma_pontino_intrinseco_diffuso',
#  'Dexter_(season_8)': 'Episodi_di_Dexter_(ottava_stagione)',
#  'Mode_of_production': 'Modo_di_produzione',
#  'Blacc_Hollywood': 'Blacc_Hollywood',
#  'Venezia_Porto_Marghera_railway_station': 'Stazione_di_Venezia_Porto_Marghera',
#  '2014_Latvian_Higher_League': 'Virslīga_2014',
#  'La_figlia_del_mago': 'La_figlia_del_mago',
#  'Halo:_Spartan_Strike': 'Halo:_Spartan_Strike',
#  'Braccialetti_rossi': 'Braccialetti_rossi',
#  'Ramon_Solsona_i_Sancho': 'Ramon_Solsona_i_Sancho',
#  'A_Sold_Life': 'Una_vita_venduta',
#  'Diocesan_Museum_of_Gallipoli': 'Museo_diocesano_(Gallipoli)',
#  'Flying_Microtonal_Banana': 'Flying_Microtonal_Banana',
#  'Ibrahim_Traoré': 'Ibrahim_Traoré',
#  'Theo_Pinson': 'Theo_Pinson',
#  'Annie_McEnroe': 'Annie_McEnroe',
#  'Alexander_Volkanovski': 'Alexander_Volkanovski',
#  "2017_Ballon_d'Or": "Pallone_d'oro_2017",
#  'Raoul_Rigault': 'Raoul_Rigault',
#  'Athletics_at_the_2019_European_Games': 'Atletica_leggera_ai_II_Giochi_europei',
#  'Antônio_Calloni': 'Antonio_Calloni',
#  'The_Order_of_Time_(book)': "L'ordine_del_tempo",
#  'Andrea_Grandoni': 'Andrea_Grandoni',
#  'Begin_Again_(Norah_Jones_album)': 'Begin_Again_(Norah_Jones)',
#  '1880': '1880',
#  'Orrorin': 'Orrorin_tugenensis',
#  'Frequency': 'Frequenza',
#  'Marble': 'Marmo',
#  '834': '834',
#  '1357': '1357',
#  '954': '954',
#  'Civil_liberties': 'Libertà_civili',
#  'Nikephoros_I_of_Constantinople': 'Niceforo_I_di_Costantinopoli',
#  'Latvian_language': 'Lingua_lettone',
#  'Greed_(1924_film)': 'Rapacità',
#  'History_of_Denmark': 'Storia_della_Danimarca',
#  '457_BC': '457_a.C.',
#  'Henry_James': 'Henry_James',
#  'Constable': 'Connestabile',
#  'The_Bends_(album)': 'The_Bends',
#  'Holly_Valance': 'Holly_Valance',
#  'Convair_F-106_Delta_Dart': 'Convair_F-106_Delta_Dart',
#  'Tatar_language': 'Lingua_tatara',
#  'Berserker': 'Berserkr',
#  'Transporter_bridge': 'Ponte_trasportatore',
#  'Maurice_Blanchot': 'Maurice_Blanchot',
#  'Saint_Lucy': 'Santa_Lucia',
#  'Maternal_effect': 'Effetto_materno',
#  'David_Davis_(British_politician)': 'David_Davis_(politico)',
#  'Betel': 'Betel_(pianta)',
#  'Tsesarevich': 'Cesarevič',
#  'Nathan_Deal': 'Nathan_Deal',
#  'Low-cost_carrier': 'Compagnia_aerea_a_basso_costo',
#  'Deryck_Cooke': 'Deryck_Cooke',
#  'Order_of_St._George': 'Ordine_di_San_Giorgio',
#  'AGC_Inc.': 'Asahi_Glass',
#  'Biretta': 'Berretta',
#  'Ralph_Records': 'Ralph_Records',
#  'State-transition_table': 'Tabella_di_transizione_di_stato',
#  'Jose_P._Laurel': 'José_Paciano_Laurel',
#  'Pieter_Boddaert': 'Pieter_Boddaert',
#  'House_of_Howard': 'Howard_(famiglia)',
#  'National_League_(ice_hockey)': 'National_League_(hockey_su_ghiaccio)',
#  "Monica's_Gang": 'La_banda_di_Monica',
#  'In_medias_res': 'In_medias_res',
#  'Sojitz': 'Sojitz',
#  'Atlantic_mackerel': 'Scomber_scombrus',
#  'Lake_Manyara': 'Lago_Manyara',
#  'Water_motorsports_at_the_1908_Summer_Olympics': 'Motonautica_ai_Giochi_della_IV_Olimpiade',
#  'Ċensu_Tabone': 'Ċensu_Tabone',
#  'Brendan_Eich': 'Brendan_Eich',
#  'Busseto': 'Busseto',
#  'Joseph_Meyer_(publisher)': 'Joseph_Meyer',
#  'Laysan_rail': 'Porzana_palmeri',
#  'Alamaailman_Vasarat': 'Alamaailman_Vasarat',
#  'Samoa_national_football_team': 'Nazionale_di_calcio_delle_Samoa',
#  'Andre_Miller': 'Andre_Miller',
#  'Jøssingfjord': 'Jøssingfjord',
#  'Monster_Hunter_(video_game)': 'Monster_Hunter',
#  'MG_MGB': 'MG_B',
#  'Francisco_Fonseca': 'Francisco_Fonseca',
#  'Guardia_Sanframondi': 'Guardia_Sanframondi',
#  'Exercise_ball': 'Palla_da_ginnastica',
#  'All_the_Troubles_of_the_World': 'Tutti_i_guai_del_mondo',
#  'Mark_Morris_(choreographer)': 'Mark_Morris',
#  'Alberto_Berasategui': 'Alberto_Berasategui',
#  'Louise_of_Hesse-Kassel': "Luisa_d'Assia-Kassel",
#  'Cobweb_plot': 'Diagramma_a_ragnatela',
#  'Rebecca_Horn': 'Rebecca_Horn',
#  'The_Rippingtons': 'The_Rippingtons',
#  'Standard-bearer': 'Portabandiera',
#  'Atziluth': 'Atziluth',
#  'Karlovy_Vary_District': 'Distretto_di_Karlovy_Vary',
#  "D'eux": "D'eux",
#  'Hoefler_Text': 'Hoefler_Text',
#  "I'll_Stick_Around": "I'll_Stick_Around",
#  'Ivy_Valentine': 'Ivy_Valentine',
#  'Rasbora': 'Rasbora',
#  'Republic_Day_(India)': 'Festa_della_Repubblica_Indiana',
#  'Fiat_Barchetta': 'Fiat_Barchetta',
#  'Antonio_Labriola': 'Antonio_Labriola',
#  'Phaenarete': 'Fenarete',
#  'QuickTime_File_Format': 'QuickTime_File_Format',
#  'Caeremoniale_Episcoporum': 'Caeremoniale_Episcoporum',
#  'Glynn_Turman': 'Glynn_Turman',
#  'Vasil_Levski_National_Stadium': 'Stadio_nazionale_Vasil_Levski',
#  'Gun.Smoke': 'Gun.Smoke',
#  'O-Parts_Hunter': '666_Satan',
#  'The_Princess_Bride_(novel)': 'La_principessa_sposa',
#  'Cathedral_Square,_Moscow': 'Piazza_delle_Cattedrali',
#  'Hyperelastic_material': 'Iperelasticità',
#  'Bnei_Yehuda_Tel_Aviv_F.C.': 'Moadon_Kaduregel_Bnei_Yehuda_Tel_Aviv',
#  "University_of_L'Aquila": "Università_degli_Studi_dell'Aquila",
#  'Adolfo_de_la_Huerta': 'Adolfo_de_la_Huerta',
#  'Fushigi_no_Kuni_no_Alice': 'Alice_nel_Paese_delle_Meraviglie_(serie_animata)',
#  'Live_in_Tokyo_(Weather_Report_album)': 'Live_in_Tokyo_(Weather_Report)',
#  'Qasr-e_Shirin': 'Qasr-e_Shirin',
#  'Bunyola': 'Bunyola',
#  'Llanera,_Asturias': 'Llanera_(Asturie)',
#  "'Til_Death": 'Til_Death_-_Per_tutta_la_vita',
#  'Crock_(comic_strip)': 'Crock',
#  'I_Could_Have_Danced_All_Night': 'I_Could_Have_Danced_All_Night',
#  'Roman_Catholic_Archdiocese_of_Sherbrooke': 'Arcidiocesi_di_Sherbrooke',
#  "1998_CONCACAF_Champions'_Cup": "CONCACAF_Champions'_Cup_1998",
#  'Montesarchio': 'Montesarchio',
#  'Bon_Voyage_(2003_film)': 'Bon_Voyage_(film_2003)',
#  'Texas_Longhorns_football': 'Texas_Longhorns_football',
#  'Sauro-class_destroyer': 'Classe_Nazario_Sauro_(cacciatorpediniere)',
#  'Tapejaridae': 'Tapejaridae',
#  'Álvaro_Gestido': 'Álvaro_Gestido',
#  'Charles_White_(American_football)': 'Charles_White',
#  'John_Brennan_(CIA_officer)': 'John_O._Brennan',
#  'Siege_of_Bursa': 'Assedio_di_Bursa',
#  'Mystery_Woman': 'La_libreria_del_mistero',
#  'Systematic_Chaos': 'Systematic_Chaos',
#  'Rick_Priestley': 'Rick_Priestley',
#  'Andrea_Sartoretti': 'Andrea_Sartoretti',
#  'Armando_Pantanelli': 'Armando_Pantanelli',
#  'Karl_Bulla': 'Karl_Bulla',
#  'Zach_Blair': 'Zach_Blair',
#  'Steven_Pasquale': 'Steven_Pasquale',
#  'Jaime_Sarlanga': 'Jaime_Sarlanga',
#  'Leeds_International_Piano_Competition': 'Concorso_pianistico_internazionale_di_Leeds',
#  'Yakut_revolt': 'Rivolta_jakuta',
#  'Enrique_Vidallé': 'Enrique_Vidallé',
#  'The_Platinum_Collection_(Queen_album)': 'The_Platinum_Collection_(Queen)',
#  'Ben_Youngs': 'Ben_Youngs',
#  'Eric_Tinkler': 'Eric_Tinkler',
#  'Brittia': 'Brittia',
#  'Great_St_Bernard_Tunnel': 'Traforo_del_Gran_San_Bernardo',
#  'Villaggio_Coppola': 'Villaggio_Coppola',
#  'Jonathan_Tropper': 'Jonathan_Tropper',
#  'Yuria_100_Shiki': 'Yuria_Type_100',
#  'Suction_(medicine)': 'Aspiratore_(medicina)',
#  'Carrara_Cathedral': 'Duomo_di_Carrara',
#  'Wilder_Pfaff': 'Cima_del_Prete',
#  'Customer_to_customer': 'Consumer_to_Consumer',
#  'Integrated_ticketing': 'Sistema_tariffario_integrato',
#  'Rail_transport_in_Sudan': 'Trasporto_ferroviario_in_Sudan',
#  'La_Gazzetta_del_Mezzogiorno': 'La_Gazzetta_del_Mezzogiorno',
#  'Loeches': 'Loeches',
#  'Girlfriend_(2004_film)': 'Girlfriend_(film_2004)',
#  'Inula_salicina': 'Inula_salicina',
#  'Aarón_Padilla_Gutiérrez': 'Aarón_Padilla_Gutiérrez',
#  'Victor_José_Pozzo': 'Víctor_Pozzo',
#  "Bologna_Children's_Book_Fair": "Bologna_Children's_Book_Fair",
#  'Fernando_Saraceni': 'Fernando_Saraceni',
#  'Carl_Fredrik_Adelcrantz': 'Carl_Fredrik_Adelcrantz',
#  'Fernando_Sucre': 'Fernando_Sucre',
#  'Roberto_de_Mattei': 'Roberto_de_Mattei',
#  'La_lettera_anonima': 'La_lettera_anonima',
#  'Naruto_Shippuden:_Ultimate_Ninja_Storm_Generations': 'Naruto_Shippuden:_Ultimate_Ninja_Storm_Generations',
#  'Cassandra_(name)': 'Cassandra_(nome)',
#  'Cuore_contro_cuore': 'Cuore_contro_cuore',
#  'Samantha_Bricio': 'Samantha_Bricio',
#  '2013_Israeli_legislative_election': 'Elezioni_parlamentari_in_Israele_del_2013',
#  'Wikipedia_Zero': 'Wikipedia_Zero',
#  'Alex_Ross_Perry': 'Alex_Ross_Perry',
#  'Siege_of_Sirmium': 'Assedio_di_Sirmio_(582)',
#  'Snowboarding_at_the_2014_Winter_Olympics': 'Snowboard_ai_XXII_Giochi_olimpici_invernali',
#  'Premier_Soccer_League': 'South_African_Premier_Division',
#  'Squeak_the_Mouse': 'Squeak_the_Mouse',
#  '2014_World_Touring_Car_Championship': 'WTCC_2014',
#  'Mercedes_F1_W05_Hybrid': 'Mercedes_F1_W05',
#  'Bismuth_oxynitrate': 'Ossinitrato_di_bismuto',
#  '2014_Latvian_parliamentary_election': 'Elezioni_parlamentari_in_Lettonia_del_2014',
#  'Sam_Hunt': 'Sam_Hunt',
#  '2014–15_AS_Monaco_FC_season': 'Association_Sportive_de_Monaco_Football_Club_2014-2015',
#  'Saša_Lukić': 'Saša_Lukić',
#  'The_Land_Before_Time_XIV:_Journey_of_the_Brave': 'The_Land_Before_Time:_Journey_of_the_Brave',
#  'Banca_Carime': 'Banca_Carime',
#  'Results_of_the_2016_Republican_Party_presidential_primaries': 'Risultati_delle_elezioni_primarie_del_Partito_Repubblicano_del_2016_per_stato',
#  'Alta_Val_Tidone': 'Alta_Val_Tidone',
#  'Humeima': 'Humeima',
#  'Francesco_Prando': 'Francesco_Prando',
#  'Daniela_Melchiorre': 'Daniela_Melchiorre',
#  'First_Epistle_to_the_Thessalonians': 'Prima_lettera_ai_Tessalonicesi',
#  'Friedrich_Bessel': 'Friedrich_Wilhelm_Bessel',
#  'Philistines': 'Filistei',
#  'Katina_Paxinou': 'Katina_Paxinou',
#  '790': '790',
#  'The_Cat_Who_Walks_Through_Walls': 'Il_gatto_che_attraversa_i_muri',
#  'Georg_Ohm': 'Georg_Ohm',
#  'South_East_England': 'Sud_Est_(Inghilterra)',
#  'Worldcon': 'Worldcon',
#  'Bringing_Up_Baby': 'Susanna!',
#  'AEC_Routemaster': 'AEC_Routemaster',
#  'Cañon_City,_Colorado': 'Cañon_City',
#  'Dorothy_Hodgkin': 'Dorothy_Crowfoot_Hodgkin',
#  'Chicopee,_Massachusetts': 'Chicopee',
#  'Convent': 'Convento',
#  'Merton_College,_Oxford': 'Merton_College',
#  'The_Ink_Spots': 'The_Ink_Spots',
#  'Aartselaar': 'Aartselaar',
#  'Graphics_Device_Interface': 'Graphics_Device_Interface',
#  'Kirov,_Kirov_Oblast': "Kirov_(Oblast'_di_Kirov)",
#  'South_Uist': 'South_Uist',
#  'Purim': 'Purim',
#  'Cry_of_Dolores': 'Grito_de_Dolores',
#  'Guilin': 'Guilin',
#  'Caraga': 'Caraga',
#  'Moscow_State_University': 'Università_statale_di_Mosca',
#  'Andrea_Del_Boca': 'Andrea_del_Boca',
#  'Is–ought_problem': 'Legge_di_Hume',
#  'Bobo-Dioulasso': 'Bobo-Dioulasso',
#  'Extracorporeal_membrane_oxygenation': 'ECMO',
#  'User-centered_design': "Progettazione_centrata_sull'utente",
#  "Richard_O'Brien": "Richard_O'Brien",
#  'Plymouth_Reliant': 'Plymouth_Reliant',
#  'Voiceless_bilabial_stop': 'Occlusiva_bilabiale_sorda',
#  'Melinda_Clarke': 'Melinda_Clarke',
#  'James_Dean_Bradfield': 'James_Dean_Bradfield',
#  'Census_geographic_units_of_Canada': 'Unità_geografiche_censuarie_del_Canada',
#  'Basilica_of_Our_Lady_of_Peace': 'Basilica_di_Nostra_Signora_della_Pace',
#  'Borough_of_Wokingham': 'Wokingham_(borough)',
#  'Mescalero_(album)': 'Mescalero_(album)',
#  'Dominican_Liberation_Party': 'Partito_della_Liberazione_Dominicana',
#  'Miranda_Cosgrove': 'Miranda_Cosgrove',
#  'David_Thewlis': 'David_Thewlis',
#  'Mindi_Abair': 'Mindi_Abair',
#  'Steinbach,_Manitoba': 'Steinbach_(Canada)',
#  'Avram_Hershko': 'Avram_Hershko',
#  'Otto_F._Kernberg': 'Otto_Kernberg',
#  'Hotspot_(Wi-Fi)': 'Hotspot_(telematica)',
#  'Maria_Soledad_Torres_y_Acosta': 'Maria_Soledad_Torres_Acosta',
#  'Malibu_Comics': 'Malibu_Comics',
#  'Monster_Rancher': 'Monster_Rancher_(serie)',
#  'Dandi,_Navsari': 'Dandi_(India)',
#  'Laos_national_football_team': 'Nazionale_di_calcio_del_Laos',
#  'Chidambaram': 'Chidambaram',
#  'Octreotide': 'Octreotide',
#  'Evan_Lysacek': 'Evan_Lysacek',
#  'Biometric_passport': 'Passaporto_biometrico',
#  'Battle_of_the_Lys_(1918)': 'Quarta_battaglia_di_Ypres',
#  'Dirty_Pair': 'Kate_e_Julie',
#  'Planet_X_(band)': 'Planet_X',
#  'Walter_Berry_(basketball)': 'Walter_Berry_(cestista)',
#  'The_Devil_Went_Down_to_Georgia': 'The_Devil_Went_Down_to_Georgia',
#  'Beniaminów': 'Beniaminów',
#  'Snow_Falling_on_Cedars_(film)': 'La_neve_cade_sui_cedri',
#  'Greatest_Hits_(Mariah_Carey_album)': 'Greatest_Hits_(Mariah_Carey)',
#  'Negidals': 'Negidal',
#  'Statutes_of_Kilkenny': 'Statuto_di_Kilkenny',
#  'Crazy_Hits': 'Crazy_Frog_Presents_Crazy_Hits',
#  'Etazeta_of_Bithynia': 'Etazeta',
#  'Passiontide': 'Tempo_di_Passione',
#  'Proton_Synchrotron': 'Proton_Synchrotron',
#  'Future_Cop:_LAPD': 'Future_Cop:_L.A.P.D.',
#  'Titus_Flavius_Petro': 'Tito_Flavio_Petrone',
#  'Submission_(combat_sports)': 'Sottomissione_(lotta)',
#  'Nadcap': 'Nadcap',
#  'Shattiwaza': 'Shattiwaza',
#  'Jack_Johnson_(posseman)': 'Jack_Johnson_(pistolero)',
#  'Ruxandra_Dragomir': 'Ruxandra_Dragomir',
#  'Rüdesheim_an_der_Nahe': 'Rüdesheim',
#  'Free_as_a_Bird': 'Free_as_a_Bird',
#  'Friends_of_God': 'Amici_di_Dio',
#  'Paphnutius_of_Thebes': 'Pafnuzio_di_Tebe',
#  'Mercury(II)_sulfate': 'Solfato_mercurico',
#  'Kanto_(comics)': 'Kanto_(personaggio)',
#  'Brindisi_Airport': 'Aeroporto_di_Brindisi-Casale',
#  'Bernd_Förster': 'Bernd_Förster',
#  'Jean_Marc_Gaspard_Itard': 'Jean_Marc_Gaspard_Itard',
#  'Lope_García_de_Castro': 'Lope_García_de_Castro',
#  'In-game_advertising': 'In-game_advertising',
#  'J._B._Hutto': 'J._B._Hutto',
#  'Social_Sciences_Citation_Index': 'Social_Sciences_Citation_Index',
#  'Tesseract_(software)': 'Tesseract_(software)',
#  'Josef_Suk_(violinist)': 'Josef_Suk_(violinista)',
#  'Bubalus_cebuensis': 'Bubalus_cebuensis',
#  'The_Chris_Isaak_Show': 'The_Chris_Isaak_Show',
#  'Mannheim_Palace': 'Castello_di_Mannheim',
#  'Lavrentiya': 'Lavrentija',
#  'Ann_Crumb': 'Ann_Crumb',
#  'Santa_Maria_di_Leuca': 'Santa_Maria_di_Leuca',
#  'Blériot_Aéronautique': 'Blériot_Aéronautique',
#  'Mark_Blaug': 'Mark_Blaug',
#  'Alexander_Pfänder': 'Alexander_Pfänder',
#  'Wagon_fort': 'Fortezza_di_carri',
#  'Alfredo,_Alfredo': 'Alfredo_Alfredo',
#  'Jean-Pierre_Cyprien': 'Jean-Pierre_Cyprien',
#  'Kitty_Kat': 'Kitty_Kat',
#  'Yıldız_Palace': 'Palazzo_di_Yıldız',
#  'Asian_Athletics_Association': 'Asian_Athletics_Association',
#  'The_Amazing_Panda_Adventure': 'Il_piccolo_panda',
#  'Flag_of_Naples': 'Bandiere_del_Regno_di_Napoli',
#  'Square_Rooms': 'Square_Rooms',
#  'Gerhard_Strack': 'Gerd_Strack',
#  'Ricardo_Santos_(footballer,_born_1987)': 'Ricardo_Henrique_da_Silva_dos_Santos',
#  'Romeo_Neri': 'Romeo_Neri',
#  '2010_NBA_All-Star_Game': 'NBA_All-Star_Weekend_2010',
#  '1359_Prieska': '1359_Prieska',
#  'Leviathan_(Auster_novel)': 'Leviatano_(Auster)',
#  'Hertha_BSC_II': 'Hertha_Berliner_Sport-Club_II',
#  'Pebble_to_a_Pearl': 'Pebble_to_a_Pearl',
#  'Potap': 'Potap',
#  'Virtus_Entella': 'Virtus_Entella',
#  'Cipriano_Efisio_Oppo': 'Cipriano_Efisio_Oppo',
#  'Hard_Time_for_Princes': 'La_congiuntura',
#  'Pierre_du_Cambout_de_Coislin': 'Pierre-Armand_du_Cambout_de_Coislin',
#  'Christ_Blessing_(Raphael)': 'Cristo_benedicente_(Raffaello)',
#  'Paolo_Moffa': 'Paolo_Moffa',
#  'Citizens_United_v._FEC': 'Cittadini_Uniti_contro_la_Commissione_delle_elezioni_federali',
#  'JaJuan_Johnson': 'JaJuan_Johnson',
#  'Lesly_Malouda': 'Lesly_Malouda',
#  'Roman_civil_war_of_350–353': 'Guerra_civile_romana_(350-353)',
#  'Reggie_Bullock': 'Reggie_Bullock',
#  'Walter_Maioli': 'Walter_Maioli',
#  'Live_in_Manchester_(Slash_album)': 'Live_in_Manchester_3_July_2010',
#  'The_Great_Escape_(Seventh_Wonder_album)': 'The_Great_Escape_(Seventh_Wonder)',
#  'Clare_Maguire': 'Clare_Maguire',
#  'Attilio_Parelli': 'Attilio_Parelli',
#  'Mortaio_da_81/14_Modello_35': 'Mortaio_da_81_Mod._35',
#  '2012_Serbian_parliamentary_election': 'Elezioni_parlamentari_in_Serbia_del_2012',
#  'Maria_Sorvillo': 'Maria_Sorvillo',
#  'JAG_(season_2)': 'Episodi_di_JAG_-_Avvocati_in_divisa_(seconda_stagione)',
#  'Batman_(1989_Ocean_video_game)': 'Batman_(videogioco_1989_Amiga)',
#  'Bram_(wrestler)': 'Bram_(wrestler)',
#  'All_the_Colors_of_the_Dark': 'Tutti_i_colori_del_buio_(film)',
#  'Just_Give_Me_a_Reason': 'Just_Give_Me_a_Reason',
#  'Alex_Len': "Alex_Len'",
#  'Willem_Levelt': 'Willem_Levelt',
#  'Mario_and_Donkey_Kong:_Minis_on_the_Move': 'Mario_and_Donkey_Kong:_Minis_on_the_Move',
#  "Athletics_at_the_1976_Summer_Olympics_–_Women's_high_jump": 'Atletica_leggera_ai_Giochi_della_XXI_Olimpiade_-_Salto_in_alto_femminile',
#  '2013–14_Eintracht_Braunschweig_season': 'Braunschweiger_Turn-_und_Sportverein_Eintracht_von_1895_2013-2014',
#  'OKO': 'OKO_Tower',
#  'Bound_2': 'Bound_2',
#  '2014_FIFA_World_Cup_Brazil_(video_game)': '2014_FIFA_World_Cup',
#  'The_Sultans_(film)': "L'amante_italiana",
#  'Doris_Bačić': 'Doris_Bačić',
#  'Gauss–Boaga_projection': 'Proiezione_di_Gauss-Boaga',
#  '2016_Philippine_general_election': 'Elezioni_generali_nelle_Filippine_del_2016',
#  'The_Divergent_Series:_Allegiant': 'The_Divergent_Series:_Allegiant',
#  '2014–15_FC_Shakhtar_Donetsk_season': "Futbol'nyj_Klub_Šachtar_2014-2015",
#  'Ken_Roczen': 'Ken_Roczen',
#  'Diocese_of_Laodicea_in_Phrygia': 'Arcidiocesi_di_Laodicea_di_Frigia',
#  'Conchita_(album)': 'Conchita_(album)',
#  'Maud_de_Belleroche': 'Maud_de_Belleroche',
#  'Lisa-Marie_Karlseng_Utland': 'Lisa-Marie_Karlseng_Utland',
#  'Monte_Scuderi': 'Monte_Scuderi',
#  'Temple_of_the_gens_Flavia': 'Tempio_della_Gens_Flavia',
#  'Marco_Drago': 'Marco_Drago_(astrofisico)',
#  'Foursome_(2016_TV_series)': 'Foursome_(serie_televisiva)',
#  'All_in_My_Head_(Flex)': 'All_in_My_Head_(Flex)',
#  'Jérémy_Desplanches': 'Jérémy_Desplanches',
#  'Ezri_Konsa': 'Ezri_Konsa',
#  'Enrico_Emanuelli': 'Enrico_Emanuelli',
#  'Luke_Fischer': 'Luke_Fischer',
#  'Jakob_Schubert': 'Jakob_Schubert',
#  'Roberts_Uldriķis': 'Roberts_Uldriķis',
#  '2019_Canadian_Grand_Prix': 'Gran_Premio_del_Canada_2019',
#  'Ferrari_Monza_SP': 'Ferrari_Monza_SP',
#  'McLaren_Speedtail': 'McLaren_Speedtail',
#  'Franziska_Gritsch': 'Franziska_Gritsch',
#  'Luca_Campogrande': 'Luca_Campogrande',
#  'Ellero': 'Ellero',
#  'Entropy': 'Entropia',
#  'Hermetic_Order_of_the_Golden_Dawn': 'Golden_Dawn',
#  'Christopher_Alexander': 'Christopher_Alexander',
#  'Intercontinental_ballistic_missile': 'Missile_balistico_intercontinentale',
#  "Lagrange's_theorem_(group_theory)": 'Teorema_di_Lagrange_(teoria_dei_gruppi)',
#  'Torque': 'Momento_meccanico',
#  'Thích_Nhất_Hạnh': 'Thích_Nhất_Hạnh',
#  'Leicestershire': 'Leicestershire',
#  'Sting_(musician)': 'Sting',
#  'Florida_Panthers': 'Florida_Panthers',
#  'Fairbanks_North_Star_Borough,_Alaska': 'Borough_di_Fairbanks_North_Star',
#  'Fourth_Crusade': 'Quarta_crociata',
#  'Ede,_Netherlands': 'Ede_(Paesi_Bassi)',
#  'Queens_of_the_Stone_Age': 'Queens_of_the_Stone_Age',
#  "King's_College,_Cambridge": "King's_College_(Cambridge)",
#  'Stored-program_computer': 'Computer_a_programma_memorizzato',
#  'Intensive_farming': 'Agricoltura_intensiva',
#  'Ethylene_glycol': 'Glicole_etilenico',
#  "Bartholin's_gland": 'Ghiandola_di_Bartolino',
#  'Muʿtazila': 'Mutazilismo',
#  'USS_Princeton_(CV-37)': 'USS_Princeton_(CV-37)',
#  'Montane_grasslands_and_shrublands': 'Praterie_e_boscaglie_montane',
#  'Blues_for_the_Red_Sun': 'Blues_for_the_Red_Sun',
#  'Extensor_carpi_ulnaris_muscle': 'Muscolo_estensore_ulnare_del_carpo',
#  'Piero_della_Francesca': 'Piero_della_Francesca',
#  'Puttaparthi': 'Puttaparthi',
#  'Brown_pelican': 'Pelecanus_occidentalis',
#  'Erlangen-Höchstadt': 'Circondario_di_Erlangen-Höchstadt',
#  'Thomas_Tallis': 'Thomas_Tallis',
#  'Music_of_Venezuela': 'Musica_in_Venezuela',
#  'Major_League_Baseball_All-Star_Game': 'Major_League_Baseball_All-Star_Game',
#  'Lambeth_Palace': 'Lambeth_Palace',
#  'Silla': 'Silla_(Corea)',
#  'San_Francisco_Chronicle': 'San_Francisco_Chronicle',
#  'Breeding_back': 'Breeding_back',
#  'Education_in_Sweden': 'Istruzione_in_Svezia',
#  'Neeme_Järvi': 'Neeme_Järvi',
#  "Vincent_d'Indy": "Vincent_d'Indy",
#  'Idrissa_Seck': 'Idrissa_Seck',
#  'Majlis': 'Majlis',
#  'Roth_(district)': 'Circondario_di_Roth',
#  'Sopwith_Pup': 'Sopwith_Pup',
#  'Cliff_Bleszinski': 'Cliff_Bleszinski',
#  'Setebos_(moon)': 'Setebos_(astronomia)',
#  'Western_swing': 'Western_swing',
#  'Franz_Aepinus': 'Ulrich_Theodor_Aepinus',
#  'Paris_Peace_Accords': 'Accordi_di_pace_di_Parigi',
#  'Wroxeter': 'Wroxeter',
#  'Eggdrop': 'Eggdrop',
#  'Gabriel_González_Videla': 'Gabriel_González_Videla',
#  'Zürich_Hauptbahnhof': 'Stazione_di_Zurigo_Centrale',
#  'Vanlandi': 'Vanlandi',
#  'Kevin_Richardson_(musician)': 'Kevin_Richardson',
#  'Final_Fight_3': 'Final_Fight_3',
#  'Rialto_Bridge': 'Ponte_di_Rialto',
#  'Volcanic_arc': 'Arco_vulcanico',
#  '1973_Argentine_Grand_Prix': "Gran_Premio_d'Argentina_1973",
#  'Currency_union': 'Unione_monetaria',
#  'Questlove': 'Questlove',
#  'The_Affair_of_the_Necklace': "L'intrigo_della_collana",
#  'Stereophonic_sound': 'Stereofonia',
#  'Shawn_Crahan': 'Shawn_Crahan',
#  'Jeroen_Tel': 'Jeroen_Tel',
#  'John_Finn': 'John_Finn',
#  'Central_Otago_District': 'Distretto_di_Central_Otago',
#  'Maurice_Schumann': 'Maurice_Schumann',
#  'Cedrus_atlantica': 'Cedrus_atlantica',
#  'Chinese_hip_hop': 'Hip_hop_cinese',
#  'Fabius_Planciades_Fulgentius': 'Fabio_Planciade_Fulgenzio',
#  'Swimming_at_the_1956_Summer_Olympics': 'Nuoto_ai_Giochi_della_XVI_Olimpiade',
#  'Trammps_(album)': 'Trammps',
#  'Eduardo_Cojuangco_Jr.': 'Eduardo_Cojuangco_Jr.',
#  'Pat_Garrett_and_Billy_the_Kid': 'Pat_Garrett_e_Billy_Kid',
#  'James_Horan_(actor)': 'James_Horan',
#  'Lester_Young': 'Lester_Young',
#  'Order_of_Adolphe_of_Nassau': 'Ordine_militare_e_civile_di_Adolfo_di_Nassau',
#  'Carlo_Marochetti': 'Carlo_Marochetti',
#  'Jerzy_Kuryłowicz': 'Jerzy_Kuryłowicz',
#  'Peter_Aerts': 'Peter_Aerts',
#  'Mirror_Master': 'Mirror_Master',
#  'Nuria_Llagostera_Vives': 'Nuria_Llagostera_Vives',
#  'Ruggero_Deodato': 'Ruggero_Deodato',
#  'Cedric_Yarbrough': 'Cedric_Yarbrough',
#  'Venus_of_Urbino': 'Venere_di_Urbino',
#  'Health_care_system_in_Japan': 'Sistema_sanitario_del_Giappone',
#  'Blanche_of_Lancaster': 'Bianca_di_Lancaster',
#  'Oleta_Adams': 'Oleta_Adams',
#  'The_Lost_Chapter_of_the_Acts_of_the_Apostles': 'Capitolo_29_degli_Atti_degli_Apostoli',
#  'Kylemore_Abbey': 'Abbazia_di_Kylemore',
#  'Jelena_Karleuša': 'Jelena_Karleuša',
#  'Nordic_combined_at_the_1980_Winter_Olympics': 'Combinata_nordica_ai_XIII_Giochi_olimpici_invernali',
#  'Polikarpov_I-153': 'Polikarpov_I-153',
#  'Be_My_Wife': 'Be_My_Wife',
#  'Joseph_Williams_(musician)': 'Joseph_Williams',
#  'Comic_Cavalcade': 'Comic_Cavalcade',
#  'Pramipexole': 'Pramipexolo',
#  'Massimo_Ranieri': 'Massimo_Ranieri',
#  'Knock_Off_(film)': 'Hong_Kong_colpo_su_colpo',
#  'Bundesautobahn_9': 'Bundesautobahn_9',
#  'Scorched_(2003_film)': 'BancoPaz',
#  'Munich_(song)': 'Munich_(singolo)',
#  'Venetian_nationalism': 'Venetismo',
#  'Power_to_the_People_(song)': 'Power_to_the_People_(John_Lennon)',
#  'Freezing_drizzle': 'Pioviggine_sopraffusa',
#  'Lost_Souls_(2000_film)': 'Lost_Souls_-_La_profezia',
#  'Linckia_laevigata': 'Linckia_laevigata',
#  'Coat_of_arms_of_Palestine': 'Stemma_della_Palestina',
#  'Rockpalast_(album)': 'Rockpalast_(album)',
#  'The_Bladerunner': 'Medicorriere',
#  '1999_European_Aquatics_Championships': 'Campionati_europei_di_nuoto_1999',
#  'Bengkulu_(city)': 'Bengkulu_(città)',
#  'Paul_Norell': 'Paul_Norell',
#  'Medole': 'Medole',
#  "San_Polo_d'Enza": "San_Polo_d'Enza",
#  'Villamar': 'Villamar',
#  ...}

# %% [markdown]
# ### **Task 5.2**
#
# Now to the **grand finale**. We will consider two periods:
# - the 35 days before the quarantine started (in the 9th of March); and
# - the 34 days after the quarantined started (including the day of the quarantine itself).
#
# Create a visualization where you can compare, for each topic, the mean **number of views** in the aforementioned periods (that is, before and after the quarantine started). **Although there is a very large number of topics, your visualization should be a compact panel, small enough to fit on an A4 page.**
#
# ---
#
# **Hint**: [Hoooray](https://seaborn.pydata.org/examples/index.html).

# %%
import seaborn as sns
plt.figure(figsize=(14,10)) # change this if needed

### ~ 5.2
### Your code here! ###

# %% [markdown]
# ### **Task 5.3**
#
# Notice that the previous analysis fails to isolate the increases or decreases in each individual topic from the overall increases or decreases in pageviews across Wikipedia in general. That is, it could be that all topics gained/lost pageviews, but some did so more than articles in general, while others did so less than articles in general. To address this issue, you should:
#
#
# 1. Normalize the pageviews counts in the dataframe created in Task 5.1. Instead of using the raw number of pageviews, you should compute, for each day, what fraction of all pageviews a topic received.
#
# 2. Create a second visualization that shows not the **raw** value of pageviews before and after, but the **relative** value that you just calculated.
#
# 3. **Discuss:** According to Task 5.2, what topics have increased in terms of the raw, absolute number of pageviews after the quarantine started? In relative, rather than absolute, terms, do these findings still hold? If not, what has changed?
#
# ---

# %%
### ~ 5.3.1
### Your code here! ###

# %%
### ~ 5.3.2
### Your code here! ###

# %%
### ~ 5.3.3
### Your text here! ###

# %% [markdown]
# ---
